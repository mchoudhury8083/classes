# %%
########## Data visualization #####################
import cufflinks as cf
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from mpl_toolkits import mplot3d

# %%
df = sns.load_dataset('iris')

# %%
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
#in the x axis the row rumbers and y axis is the value
df.plot()
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area', alpha=0.9)
# Out:
# <AxesSubplot:>

# %%
df.plot(kind = 'area', alpha=0.9, stacked= False)
# Out:
# <AxesSubplot:>

# %%
df.plot.scatter(x='sepal_length', y ='sepal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='sepal_width'>

# %%
#There is a growth, x and y axis are dependable
df.plot.scatter(x='sepal_length', y ='petal_width')
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df.plot.scatter(x='sepal_length', y ='petal_width', c ='sepal_width', s=100)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
# C for color and S for size
df.plot.scatter(x='sepal_length', y ='petal_width', c ='sepal_width', s=df['sepal_length']*20)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
df.plot.hexbin(x='sepal_length', y ='petal_width', gridsize=10, cmap ='viridis' )
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='petal_width'>

# %%
from mpl_toolkits import mplot3d

# %%
x= np.linspace(-1,6, 30)

# %%
y = np.linspace(-1, 6,30)

# %%
x
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
y
# Out:
# array([-1.        , -0.75862069, -0.51724138, -0.27586207, -0.03448276,
#         0.20689655,  0.44827586,  0.68965517,  0.93103448,  1.17241379,
#         1.4137931 ,  1.65517241,  1.89655172,  2.13793103,  2.37931034,
#         2.62068966,  2.86206897,  3.10344828,  3.34482759,  3.5862069 ,
#         3.82758621,  4.06896552,  4.31034483,  4.55172414,  4.79310345,
#         5.03448276,  5.27586207,  5.51724138,  5.75862069,  6.        ])

# %%
def sin_fun(x,y):
    return np.sin(np.sqrt(x**2 + y**2))

# %%
z = x+ y

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(x,y,z)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# Text(0.5, 0, 'z')

# %%
ax = plt.axes(projection = '3d')
ax.plot3D(df['sepal_length'],df['sepal_width'],df['petal_width'])
ax.set_xlabel('sepal_length')
ax.set_ylabel('sepal_width')
ax.set_zlabel('petal_width')
# Out:
# Text(0.5, 0, 'petal_width')

# %%
#df.plot(figsize(20,10))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [53], in <cell line: 1>()
# ----> 1 df.plot(figsize(20,10))
#
# NameError: name 'figsize' is not defined

# %%
#full line graph , to do a row wise comparision
df.plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:22].plot(kind='bar',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
df.iloc[5:11]
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species
# 5            5.4          3.9           1.7          0.4  setosa
# 6            4.6          3.4           1.4          0.3  setosa
# 7            5.0          3.4           1.5          0.2  setosa
# 8            4.4          2.9           1.4          0.2  setosa
# 9            4.9          3.1           1.5          0.1  setosa
# 10           5.4          3.7           1.5          0.2  setosa

# %%
df.iloc[5:22].plot(kind='barh',figsize=(20,10))
# Out:
# <AxesSubplot:>

# %%
#histogram represent range and frequency , with in a range how many data points are availble
df.plot(kind='hist',figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['sepal_length'].plot(kind='hist', figsize=(20,10))
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df.hist(figsize=(20,10), color = 'g' , alpha= .9)
# Out:
# array([[<AxesSubplot:title={'center':'sepal_length'}>,
#         <AxesSubplot:title={'center':'sepal_width'}>],
#        [<AxesSubplot:title={'center':'petal_length'}>,
#         <AxesSubplot:title={'center':'petal_width'}>]], dtype=object)

# %%
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.9.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.iplot()
# Out:
# <div>                            <div id="633fa9c9-0c40-40f3-a5b2-1b9358130f7b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length' , y ='sepal_width', kind = 'scatter' , mode ='markers')
# Out:
# <div>                            <div id="4b611a79-02d4-4c5c-a755-3ee3cb875b5a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df.iplot(x='sepal_length' , y ='sepal_width',z= 'petal_length' ,size = 'petal_length', kind='bubble3d')
# Out:
# <div>                            <div id="75a656ac-522c-4a5f-abca-0ec191267629" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
df1 = sns.load_dataset('tips')

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df1.plot(x='total_bill', y='tip', kind ='scatter')
# Out:
# <AxesSubplot:xlabel='total_bill', ylabel='tip'>

# %%
df1.iplot(x='total_bill', y='tip', kind ='scatter' ,mode ='markers')
# Out:
# <div>                            <div id="97f18bc3-7d4d-4217-8ff9-18cee7ff03b8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.relplot(x='total_bill', y='tip', data=df1, hue= 'time')

# %%
df1['smoker'].value_counts()
# Out:
# No     151
# Yes     93
# Name: smoker, dtype: int64

# %%
sns.relplot(x='total_bill', y='tip', data=df1, hue= 'time', style ='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=df1, hue= 'sex', style ='smoker')

# %%
sns.relplot(x='total_bill', y='tip', data=df1, hue= 'size', style ='size')

# %%
sns.relplot(x='total_bill', y='tip', data=df1, col ='time')

# %%
sns.relplot(x='sepal_length', y='sepal_width', data=df, col ='species')

# %%
sns.relplot(x='total_bill', y='tip', data=df1, col ='day')

# %%
sns.catplot(x='day', y ='total_bill', data=df1)

# %%
sns.pairplot(df1)

# %%
df.scatter_matrix()
# Out:
# <div>                            <div id="79c4426d-24e5-4461-8c07-86b7f001c975" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %%
sns.jointplot(x =df1.total_bill, y = df1.tip)

# %%
sns.jointplot(x =df1.total_bill, y = df1.tip, kind = 'hex')

# %%
sns.pairplot(df1)

# %%
sns.regplot(x= df1.total_bill , y = df1.tip)
sns.set(rc={'figure.figsize':(20,10)})

# %%
sns.load_dataset('car_crashes')
# Out:
#     total  speeding  alcohol  not_distracted  no_previous  ins_premium  \
# 0    18.8     7.332    5.640          18.048       15.040       784.55
# 1    18.1     7.421    4.525          16.290       17.014      1053.48
# 2    18.6     6.510    5.208          15.624       17.856       899.47
# 3    22.4     4.032    5.824          21.056       21.280       827.34
# 4    12.0     4.200    3.360          10.920       10.680       878.41
# 5    13.6     5.032    3.808          10.744       12.920       835.50
# 6    10.8     4.968    3.888           9.396        8.856      1068.73
# 7    16.2     6.156    4.860          14.094       16.038      1137.87
# 8     5.9     2.006    1.593           5.900        5.900      1273.89
# 9    17.9     3.759    5.191          16.468       16.826      1160.13
# 10   15.6     2.964    3.900          14.820       14.508       913.15
# 11   17.5     9.450    7.175          14.350       15.225       861.18
# ...

# %%
import plotly.express as px
fig = px.scatter(df1, x ="total_bill" , y ="tip" ,color ='time')
fig.show()
# Out:
# <div>                            <div id="50cd6a89-3774-4991-8807-e7f26ba91e02" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("50cd6a89-3774-4991-8807-e7f26ba91e02")) {                    Plotly.newPlot(                        "50cd6a89-3774-4991-8807-e7f26ba91e02",                        [{"hovertemplate":"time=Dinner<br>total_bill=%{x}<br>tip=%{y}<extra></extra>","legendgroup":"Dinner","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"Dinner","orientation":"v","showlegend":true,"x":[16.99,10.34,21.01,23.68,24.59,25.29,8.77,26.88,15.04,14.78,10.27,35.26,15.42,18.43,14.83,21.58,10.33,16.29,16.97,20.65,17.92,20.29,15.77,39.42,19.82,17.81,13.37,12.69,21.7,19.65,9.55,18.35,15.06,20.69,17.78,24.06,16.31,16.93,18.69,31.27,16.04,17.
# ...

# %%
import plotly.express as px
fig = px.bar(df1, x='sex', y="total_bill" , color="smoker" ,barmode="group")
fig.show()
# Out:
# <div>                            <div id="56110f8f-4cec-4642-b6c9-41258b8fbeb9" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("56110f8f-4cec-4642-b6c9-41258b8fbeb9")) {                    Plotly.newPlot(                        "56110f8f-4cec-4642-b6c9-41258b8fbeb9",                        [{"alignmentgroup":"True","hovertemplate":"smoker=No<br>sex=%{x}<br>total_bill=%{y}<extra></extra>","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":true,"textposition":"auto","x":["Female","Male","Male","Male","Female","Male","Male","Male","Male","Male","Male","Female","Male","Male","Female","Male","Female","Male","Female","Male","Male","Female","Female","Male","Male","Male","Male
# ...
